# %% [markdown]
# <a href="https://colab.research.google.com/github/kurttest149058/ai-data-science/blob/main/first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ask the student to enter their name

# %%
name = input("what is your name: ")
# Out:
# what is your name: allison

# %%
scores = [85, 90, 95]
average = sum(scores) / len(scores)
print("hello, " + name)
print("your average score is " + str(average))
# Out:
# hello, allison
# your average score is 90.0
